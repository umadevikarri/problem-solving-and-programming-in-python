# %% [markdown]
# ## Read csv and table from data from server or online

# %%
import pandas as ps

# %%
s=ps.read_csv("income_example.csv")

# %%
s
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  62993  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
s['2005']
# Out:
# 0    37150
# 1    55891
# 2    45245
# 3    36658
# 4    51755
# Name: 2005, dtype: int64

# %%
s[['2005','2006','2007']]
# Out:
#     2005   2006   2007
# 0  37150  37952  42212
# 1  55891  56418  62993
# 2  45245  46657  62993
# 3  36658  37057  40795
# 4  51755  55319  55734

# %%
s[1:4]
# Out:
#        GEOID     State   2005   2006   2007   2008   2009   2010   2011  \
# 1  04000US02    Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04   Arizona  45245  46657  62993  46914  45739  46896  48621
# 3  04000US05  Arkansas  36658  37057  40795  39586  36538  38587  41302
#
#     2012   2013
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919

# %%
s[1:2]
# Out:
#        GEOID   State   2005   2006   2007   2008   2009   2010   2011   2012  \
# 1  04000US02  Alaska  55891  56418  62993  63989  61604  57848  57431  63648
#
#     2013
# 1  61137

# %%
s['2006']
# Out:
# 0    37952
# 1    56418
# 2    46657
# 3    37057
# 4    55319
# Name: 2006, dtype: int64

# %%
s['2006'][2]
# Out:
# 46657

# %%
s[2:3]
# Out:
#        GEOID    State   2005   2006   2007   2008   2009   2010   2011   2012  \
# 2  04000US04  Arizona  45245  46657  62993  46914  45739  46896  48621  47044
#
#     2013
# 2  50602

# %%
s.iloc[2,4]
# Out:
# 62993

# %%
s.iloc[:,1:3]
# Out:
#         State   2005
# 0     Alabama  37150
# 1      Alaska  55891
# 2     Arizona  45245
# 3    Arkansas  36658
# 4  California  51755

# %%
s.iloc[:,2:]
# Out:
#     2005   2006   2007   2008   2009   2010   2011   2012   2013
# 0  37150  37952  42212  44476  39980  40933  42590  43464  41381
# 1  55891  56418  62993  63989  61604  57848  57431  63648  61137
# 2  45245  46657  62993  46914  45739  46896  48621  47044  50602
# 3  36658  37057  40795  39586  36538  38587  41302  39018  39919
# 4  51755  55319  55734  57014  56134  54283  53367  57020  57528

# %%
s.iloc[:,5:]
# Out:
#     2008   2009   2010   2011   2012   2013
# 0  44476  39980  40933  42590  43464  41381
# 1  63989  61604  57848  57431  63648  61137
# 2  46914  45739  46896  48621  47044  50602
# 3  39586  36538  38587  41302  39018  39919
# 4  57014  56134  54283  53367  57020  57528

# %%
s.iloc[:,2]
# Out:
# 0    37150
# 1    55891
# 2    45245
# 3    36658
# 4    51755
# Name: 2005, dtype: int64

# %%
s.iloc[:,2].mean()
# Out:
# 45339.8

# %%
s.iloc[:,[2,5,7]].sum()
# Out:
# 2005    226699
# 2008    251979
# 2010    238547
# dtype: int64

# %%
s.iloc[:,6].prod()
# Out:
# 6209617939067354560

# %%
s.iloc[:,3].min()
# Out:
# 37057

# %%
s.iloc[:,[2,4,6,8]].max()
# Out:
# 2005    55891
# 2007    62993
# 2009    61604
# 2011    57431
# dtype: int64

# %%
s.loc[2,'State']  # method 1
# Out:
# 'Arizona'

# %%
s.iloc[2,1] # method 2
# Out:
# 'Arizona'

# %%
s.loc[4,'2009']
# Out:
# 56134

# %%
s.loc[(s['2006']>50000) & (s['2006']<60000)]
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 1  63648  61137
# 4  57020  57528

# %%
s.loc[(s['2009']>50000) | (s['2010']<60000)]
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  62993  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
s.loc[(s['2009']>50000) & (s['2010']<60000)]
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 1  63648  61137
# 4  57020  57528

# %%
s['2007'][2]
# Out:
# 62993

# %%
s['2007'][2]='65000'
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
s
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  65000  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
p=ps.read_csv("http://bit.ly/imdbratings") 
p
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
p.shape
# Out:
# (979, 6)

# %%
p.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
p.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
p.tail()
# Out:
#      star_rating                                            title  \
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# ...

# %%
p.sort_values(by="star_rating",axis=0,ascending=False)
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 13           8.8                                       Forrest Gump
# 14           8.8              The Lord of the Rings: The Two Towers
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# ...

# %%
p.sort_values(by="star_rating",axis=0,ascending=False).head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
p['genre']=='comedy'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 949    False
# 950    False
# 951    False
# 952    False
# 953    False
# 954    False
# 955    False
# 956    False
# 957    False
# 958    False
# 959    False
# 960    False
# 961    False
# 962    False
# 963    False
# 964    False
# 965    False
# 966    False
# 967    False
# 968    False
# 969    False
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Name: genre, Length: 979, dtype: bool

# %%
p.loc[p['genre']=="comedy"]
# Out:
# Empty DataFrame
# Columns: [star_rating, title, content_rating, genre, duration, actors_list]
# Index: []

# %%
t=ps.read_table("http://bit.ly/chiporders")
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.

# %%
t
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
t.set_index('order_id')
# Out:
#           quantity                              item_name  \
# order_id
# 1                1           Chips and Fresh Tomato Salsa
# 1                1                                   Izze
# 1                1                       Nantucket Nectar
# 1                1  Chips and Tomatillo-Green Chili Salsa
# 2                2                           Chicken Bowl
# 3                1                           Chicken Bowl
# 3                1                          Side of Chips
# 4                1                          Steak Burrito
# 4                1                       Steak Soft Tacos
# 5                1                          Steak Burrito
# 5                1                    Chips and Guacamole
# 6                1                   Chicken Crispy Tacos
# 6                1                     Chicken Soft Tacos
# 7                1                           Chicken Bowl
# 7                1                    Chips and Guacamole
# ...

# %%
k=ps.read_table("http://bit.ly/movieusers")

k
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.
#           1|24|M|technician|85711
# 0              2|53|F|other|94043
# 1             3|23|M|writer|32067
# 2         4|24|M|technician|43537
# 3              5|33|F|other|15213
# 4          6|42|M|executive|98101
# 5      7|57|M|administrator|91344
# 6      8|36|M|administrator|05201
# 7            9|29|M|student|01002
# 8            10|53|M|lawyer|90703
# 9             11|39|F|other|30329
# 10            12|28|F|other|06405
# 11         13|47|M|educator|29206
# 12        14|45|M|scientist|55106
# 13         15|49|F|educator|97301
# 14    16|21|M|entertainment|10309
# 15       17|30|M|programmer|06355
# 16            18|35|F|other|37212
# 17        19|40|M|librarian|02138
# 18        20|42|F|homemaker|95660
# 19           21|26|M|writer|30068
# 20           22|25|M|writer|40206
# ...

# %%
ps.read_table("http://bit.ly/movieusers",sep="|")
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.
#        1  24  M     technician  85711
# 0      2  53  F          other  94043
# 1      3  23  M         writer  32067
# 2      4  24  M     technician  43537
# 3      5  33  F          other  15213
# 4      6  42  M      executive  98101
# 5      7  57  M  administrator  91344
# 6      8  36  M  administrator  05201
# 7      9  29  M        student  01002
# 8     10  53  M         lawyer  90703
# 9     11  39  F          other  30329
# 10    12  28  F          other  06405
# 11    13  47  M       educator  29206
# 12    14  45  M      scientist  55106
# 13    15  49  F       educator  97301
# 14    16  21  M  entertainment  10309
# 15    17  30  M     programmer  06355
# 16    18  35  F          other  37212
# 17    19  40  M      librarian  02138
# 18    20  42  F      homemaker  95660
# ...

# %%
header_names=['RollNo','Age',"Gender","Job","Salary"]
g=ps.read_table("http://bit.ly/movieusers",sep="|",header=None,names=header_names)

g
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead.
#      RollNo  Age Gender            Job Salary
# 0         1   24      M     technician  85711
# 1         2   53      F          other  94043
# 2         3   23      M         writer  32067
# 3         4   24      M     technician  43537
# 4         5   33      F          other  15213
# 5         6   42      M      executive  98101
# 6         7   57      M  administrator  91344
# 7         8   36      M  administrator  05201
# 8         9   29      M        student  01002
# 9        10   53      M         lawyer  90703
# 10       11   39      F          other  30329
# 11       12   28      F          other  06405
# 12       13   47      M       educator  29206
# 13       14   45      M      scientist  55106
# 14       15   49      F       educator  97301
# 15       16   21      M  entertainment  10309
# 16       17   30      M     programmer  06355
# ...

# %%
g.loc[g['Age']>30]
# Out:
#      RollNo  Age Gender            Job Salary
# 1         2   53      F          other  94043
# 4         5   33      F          other  15213
# 5         6   42      M      executive  98101
# 6         7   57      M  administrator  91344
# 7         8   36      M  administrator  05201
# 9        10   53      M         lawyer  90703
# 10       11   39      F          other  30329
# 12       13   47      M       educator  29206
# 13       14   45      M      scientist  55106
# 14       15   49      F       educator  97301
# 17       18   35      F          other  37212
# 18       19   40      M      librarian  02138
# 19       20   42      F      homemaker  95660
# 24       25   39      M       engineer  55107
# 25       26   49      M       engineer  21044
# 26       27   40      F      librarian  30030
# 27       28   32      M         writer  55369
# 28       29   41      M     programmer  94043
# 33       34   38      F  administrator  42141
# ...

# %%
g['Increment_salary']=g['Salary']+" "+'+10%'

# %%
g
# Out:
#      RollNo  Age Gender            Job Salary Increment_salary
# 0         1   24      M     technician  85711       85711 +10%
# 1         2   53      F          other  94043       94043 +10%
# 2         3   23      M         writer  32067       32067 +10%
# 3         4   24      M     technician  43537       43537 +10%
# 4         5   33      F          other  15213       15213 +10%
# 5         6   42      M      executive  98101       98101 +10%
# 6         7   57      M  administrator  91344       91344 +10%
# 7         8   36      M  administrator  05201       05201 +10%
# 8         9   29      M        student  01002       01002 +10%
# 9        10   53      M         lawyer  90703       90703 +10%
# 10       11   39      F          other  30329       30329 +10%
# 11       12   28      F          other  06405       06405 +10%
# 12       13   47      M       educator  29206       29206 +10%
# 13       14   45      M      scientist  55106       55106 +10%
# ...
